# %%
import pandas as pd
from scipy import stats
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_excel('8473GERAL-BASE.xlsx')

# %%
#Criar DF
'''
df = pd.DataFrame({'Aluno' : ["Wilfred", "Abbie", "Harry", "Julia", "Carrie"],
                   'Faltas' : [3,4,2,1,4],
                   'Prova' : [2,7,5,10,6],
                   'Seminário': [8.5,7.5,9.0,7.5,8.0]})

'''

# %%
df.head(2)

# %%
df.shape #Tupla quantidade de linhas e colunas
# Out:
# (47, 32)

# %%
df.columns
# Out:
# 'Cultivar '

# %%
df.index()
# Out:
# RangeIndex(start=0, stop=47, step=1)

# %%
print(df.columns[0])
# Out:
# Cultivar

# %%
#For para listagem de colunas
for c in range(0,32):
  print(df.columns[c])

# %%
#Primeira correlação
#Criar nova tabela
#dfP = pd.DataFrame({'GU':['GU','Mancha Purpura'], 'Mancha Purpura'})

#Correlação
coluna = df.values['0']  #retorna valores de linha
coluna

# %%
#df.corr() Correlação Pearson por padrão
dfCorr = df.corr(method='pearson')
dfCorr.to_excel('P-8473.xlsx', index=True)  #Salvar excel index true pois primeira coluna é  listagem
